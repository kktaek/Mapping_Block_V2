# %%
import pandas as pd
import numpy as np
import modeltest as deep
import experiment as exp
import myutil as util
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Reshape, UpSampling2D, Flatten, MaxPooling2D
from tensorflow.keras.initializers import RandomNormal
import tensorflow.keras as keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

import tensorflow as tf
import importlib
importlib.reload(deep)
importlib.reload(exp)
# Out:
# <module 'experiment' from 'C:\\Users\\kyeongtaek\\generative_model\\land_sat\\experiment.py'>

# %%
#파일 읽기
filepath_german_csv = 'sat.csv'
d_german_df = pd.read_csv(filepath_german_csv)

#numpy 변환
d_german_np = np.array(d_german_df)

# sample 수, 특징 수 등 계산
n_row = d_german_np.shape[0]
n_features = d_german_np.shape[1]-1

# 입력과 출력 데이터 분리
x = d_german_np[:, :n_features]
y = d_german_np[:, n_features]-1

#정규화
x_norm = (x - np.min(x,0))/ (np.max(x,0) - np.min(x,0))
y_norm = (y - np.min(y,0))/ (np.max(y,0) - np.min(y,0))

# %%
[x_new, x_val, x_test, y_train_new, y_val, y_test_new] = exp.split_data(x, y, test_ratio=0.0, val_ratio=0.1)

# %%
# 10fold validation 수행여부
bTenFoldValidation = True
if not bTenFoldValidation:  # 학습 & 테스트를 1회만 수행하는 경우
    # 데이터 분할
    [x_train, x_val, x_test, y_train, y_val, y_test] = exp.split_data(x, y, test_ratio=0.0, val_ratio=0.1)

    # 모델 불러오기 & 컴파일
    m = deep.get_model_gen(x.shape[1:])
    m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    # 학습시 사용하는 옵션
    train_options = exp.TrainParams(m, epochs=500, batch_size_per_class=32)

    # 학습
    result = exp.train_batches_with_random_selection(train_options, x_train, y_train, x_val, y_val)

    # 테스트
    if(x_test.shape[0] > 0):
        test_acc_tmp = np.sum(np.argmax(np.squeeze(result.model.predict(x_test)), -1) == y_test) / y_test.shape[0]
        print(f'test_acc:{test_acc_tmp}')
    # 결과 출력

    plt.plot(result.train_acc)
    plt.plot(result.val_acc)
    plt.show()

else:  # N fold Validation
    idx = np.array(range(n_row))
    np.random.shuffle(idx)  # 데이터 인덱스 섞기

    N = 10
    total = 0
    nClass = 2
    cm = np.zeros([N, nClass, nClass])
    for i in range(N):
        # Train/Test 데이터 분할
        [x_train, x_test, y_train, y_test] = exp.split_data_for_N_fold_validation(x_new, y_train_new, fold=N, idx=i)

        # 모델 불러오기 & 컴파일
        m = deep.get_model_map_fun(x.shape[1:])
        #m = deep.get_model(x.shape[1:])

        # m = deep.get_model(x.shape[1:])
        m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

        # 학습시 사용하는 옵션
        train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=256)

        # 학습
        result = exp.train_batches_with_random_selection(train_options, x_train, y_train, bVerbose=False)

        # 테스트
        o = np.argmax(np.squeeze(result.model.predict(x_test)), -1)
        test_acc_tmp = np.sum(o == y_test) / y_test.shape[0]
        #for j in range(y_test.shape[0]):
            #cm[i, int(y_test[j]), int(o[j])] += 1  #Confusion Matrix 계산

        # 결과 출력
        print(f'{i}/{N}\t test_acc:{test_acc_tmp}')
        plt.plot(result.train_acc)
        plt.plot(result.val_acc)
        plt.show()
        total = total + test_acc_tmp

ave = total/10
print(f'average accuracy : {ave}')
# Out:
# 19/19 [==============================] - 0s 3ms/step
# 0/10	 test_acc:0.917098445595855
# 19/19 [==============================] - 0s 3ms/step
# 1/10	 test_acc:0.9101899827288429
# 19/19 [==============================] - 0s 3ms/step
# 2/10	 test_acc:0.9067357512953368
# 19/19 [==============================] - 0s 3ms/step
# 3/10	 test_acc:0.9119170984455959
# 19/19 [==============================] - 0s 3ms/step
# 4/10	 test_acc:0.9086206896551724
# 19/19 [==============================] - 0s 2ms/step
# 5/10	 test_acc:0.9136442141623489
# 19/19 [==============================] - 0s 3ms/step
# 6/10	 test_acc:0.9032815198618307
# 19/19 [==============================] - 0s 1ms/step
# 7/10	 test_acc:0.8894645941278065
# 19/19 [==============================] - 0s 2ms/step
# 8/10	 test_acc:0.9205526770293609

# %%
# 10fold validation 수행여부
bTenFoldValidation = True
if not bTenFoldValidation:  # 학습 & 테스트를 1회만 수행하는 경우
    # 데이터 분할
    [x_train, x_val, x_test, y_train, y_val, y_test] = exp.split_data(x, y, test_ratio=0.0, val_ratio=0.1)

    # 모델 불러오기 & 컴파일
    m = deep.get_model_gen(x.shape[1:])
    m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    # 학습시 사용하는 옵션
    train_options = exp.TrainParams(m, epochs=500, batch_size_per_class=32)

    # 학습
    result = exp.train_batches_with_random_selection(train_options, x_train, y_train, x_val, y_val)

    # 테스트
    if(x_test.shape[0] > 0):
        test_acc_tmp = np.sum(np.argmax(np.squeeze(result.model.predict(x_test)), -1) == y_test) / y_test.shape[0]
        print(f'test_acc:{test_acc_tmp}')
    # 결과 출력

    plt.plot(result.train_acc)
    plt.plot(result.val_acc)
    plt.show()

else:  # N fold Validation
    idx = np.array(range(n_row))
    np.random.shuffle(idx)  # 데이터 인덱스 섞기

    N = 10
    total = 0
    nClass = 2
    cm = np.zeros([N, nClass, nClass])
    for i in range(N):
        # Train/Test 데이터 분할
        [x_train, x_test, y_train, y_test] = exp.split_data_for_N_fold_validation(x, y, fold=N, idx=i)

        # 모델 불러오기 & 컴파일
        m = deep.get_model_map_fun(x.shape[1:])
        #m = deep.get_model(x.shape[1:])

        # m = deep.get_model(x.shape[1:])
        m.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

        # 학습시 사용하는 옵션
        train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=256)

        # 학습
        result = exp.train_batches_with_random_selection_for_sparse(train_options, x_train, y_train, bVerbose=False)

        #mapping block 학습 결과 저장
        intermediate_layer_model = tf.keras.Model(inputs=m.input, outputs=m.layers[12].output)
        
        #final_model 불러오기
        m_f = deep.final_model(x.shape[1:], intermediate_layer_model, intermediate_layer_model.output.shape[1:])
        
        m_f.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
        
        train_options_f = exp.TrainParams(m_f, epochs=2000, batch_size_per_class=256)
        
        result_f = exp.train_batches_with_random_selection(train_options_f, x_train, y_train, bVerbose=False)
        
        # 테스트
        o = np.argmax(np.squeeze(result_f.model.predict(x_test)), -1)
        test_acc_tmp = np.sum(o == y_test) / y_test.shape[0]
        #for j in range(y_test.shape[0]):
            #cm[i, int(y_test[j]), int(o[j])] += 1  #Confusion Matrix 계산

        # 결과 출력
        print(f'{i}/{N}\t test_acc:{test_acc_tmp}')
        plt.plot(result_f.train_acc)
        plt.plot(result_f.val_acc)
        plt.show()
        total = total + test_acc_tmp

ave = total/10
print(f'average accuracy : {ave}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 50
#      47 train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=256)
#      49 # 학습
# ---> 50 result = exp.train_batches_with_random_selection_for_sparse(train_options, x_train, y_train, bVerbose=False)
#      52 #mapping block 학습 결과 저장
#      53 intermediate_layer_model = tf.keras.Model(inputs=m.input, outputs=m.layers[12].output)
#
# AttributeError: module 'experiment' has no attribute 'train_batches_with_random_selection_for_sparse'

# %%
m_f.summary()
# Out:
# Model: "Final_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  InputLayer (InputLayer)     [(None, 36)]              0
#
#  model_20 (Functional)       (None, 4096)              182289
#
#  sequential_19 (Sequential)  (None, 7)                 17183895
#
# =================================================================
# Total params: 17,366,184
# Trainable params: 17,349,704
# Non-trainable params: 16,480
# _________________________________________________________________

# %%
average accuracy : 0.8983626826888711
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 4096)              16781312
#
#  batch_normalization_20 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  reshape_20 (Reshape)        (None, 64, 64, 1)         0
#
#  conv2d_120 (Conv2D)         (None, 64, 64, 16)        160
#
#  conv2d_121 (Conv2D)         (None, 64, 64, 16)        2320
#
#  activation_60 (Activation)  (None, 64, 64, 16)        0
#
#  max_pooling2d_60 (MaxPoolin  (None, 31, 31, 16)       0
#  g2D)
#
#  conv2d_122 (Conv2D)         (None, 31, 31, 32)        4640
#
#  conv2d_123 (Conv2D)         (None, 31, 31, 32)        9248
#
#  activation_61 (Activation)  (None, 31, 31, 32)        0
#
#  max_pooling2d_61 (MaxPoolin  (None, 15, 15, 32)       0
#  g2D)
#
#  conv2d_124 (Conv2D)         (None, 15, 15, 64)        18496
#
#  conv2d_125 (Conv2D)         (None, 15, 15, 64)        36928
#
#  activation_62 (Activation)  (None, 15, 15, 64)        0
#
#  max_pooling2d_62 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_20 (Flatten)        (None, 3136)              0
#
#  dense_61 (Dense)            (None, 100)               313700
#
#  dense_62 (Dense)            (None, 7)                 707
#
# =================================================================
# Total params: 17,183,895
# Trainable params: 17,175,703
# Non-trainable params: 8,192
# _________________________________________________________________
