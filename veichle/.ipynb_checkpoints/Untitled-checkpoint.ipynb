# %%
import pandas as pd
import numpy as np
import modeltest as deep
import experiment as exp
import myutil as util
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Reshape, UpSampling2D, Flatten, MaxPooling2D
from tensorflow.keras.initializers import RandomNormal
import tensorflow.keras as keras
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

import tensorflow as tf
import importlib
importlib.reload(deep)
importlib.reload(exp)
# Out:
# <module 'experiment' from 'C:\\Users\\kyeongtaek\\generative_model\\veichle\\experiment.py'>

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9551474845584975902
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5471625216
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15490310836957023102
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
#파일 읽기
filepath_german_csv = 'xamain.csv'
d_german_df = pd.read_csv(filepath_german_csv)

#numpy 변환
d_german_np = np.array(d_german_df)

# sample 수, 특징 수 등 계산
n_row = d_german_np.shape[0]
n_features = d_german_np.shape[1]-1

# 입력과 출력 데이터 분리
x = d_german_np[:, :n_features]
y = d_german_np[:, n_features]

#정규화
x_norm = (x - np.min(x,0))/ (np.max(x,0) - np.min(x,0))
y_norm = (y - np.min(y,0))/ (np.max(y,0) - np.min(y,0))

# %%
# 10fold validation 수행여부
bTenFoldValidation = True
if not bTenFoldValidation:  # 학습 & 테스트를 1회만 수행하는 경우
    # 데이터 분할
    [x_train, x_val, x_test, y_train, y_val, y_test] = exp.split_data(x_norm, y, test_ratio=0.0, val_ratio=0.2)

    # 모델 불러오기 & 컴파일
    m = deep.get_model_gen(x.shape[1:])
    m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

    # 학습시 사용하는 옵션
    train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=128)

    # 학습
    result = exp.train_batches_with_random_selection(train_options, x_train, y_train, x_val, y_val)

    # 테스트
    if(x_test.shape[0] > 0):
        test_acc_tmp = np.sum(np.argmax(np.squeeze(result.model.predict(x_test)), -1) == y_test) / y_test.shape[0]
        print(f'test_acc:{test_acc_tmp}')
    # 결과 출력

    plt.plot(result.train_acc)
    plt.plot(result.val_acc)
    plt.show()

else:  # N fold Validation
    idx = np.array(range(n_row))
    np.random.shuffle(idx)  # 데이터 인덱스 섞기

    N = 10
    total = 0
    nClass = 2
    cm = np.zeros([N, nClass, nClass])
    for i in range(N):
        # Train/Test 데이터 분할
        [x_train, x_test, y_train, y_test] = exp.split_data_for_N_fold_validation(x, y, fold=N, idx=i)

        # 모델 불러오기 & 컴파일
        m = deep.get_model_map_fun(x.shape[1:])
        #m = deep.get_model(x.shape[1:])

        # m = deep.get_model(x.shape[1:])
        m.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

        # 학습시 사용하는 옵션
        train_options = exp.TrainParams(m, epochs=3000, batch_size_per_class=128)

        # 학습
        result = exp.train_batches_with_random_selection(train_options, x_train, y_train, bVerbose=False)

        # 테스트
        o = np.argmax(np.squeeze(result.model.predict(x_test)), -1)
        test_acc_tmp = np.sum(o == y_test) / y_test.shape[0]
        #for j in range(y_test.shape[0]):
            #cm[i, int(y_test[j]), int(o[j])] += 1  #Confusion Matrix 계산

        # 결과 출력
        print(f'{i}/{N}\t test_acc:{test_acc_tmp}')
        plt.plot(result.train_acc)
        plt.plot(result.val_acc)
        plt.show()
        total = total + test_acc_tmp

ave = total/10
print(f'average accuracy : {ave}')
# Out:
# 3/3 [==============================] - 0s 10ms/step
# 0/10	 test_acc:0.8588235294117647
# 3/3 [==============================] - 0s 6ms/step
# 1/10	 test_acc:0.8095238095238095
# 3/3 [==============================] - 0s 5ms/step
# 2/10	 test_acc:0.8117647058823529
# 3/3 [==============================] - 0s 8ms/step
# 3/10	 test_acc:0.8928571428571429
# 3/3 [==============================] - 0s 6ms/step
# 4/10	 test_acc:0.8
# 3/3 [==============================] - 0s 2ms/step
# 5/10	 test_acc:0.7764705882352941
# 3/3 [==============================] - 0s 3ms/step
# 6/10	 test_acc:0.7738095238095238
# 3/3 [==============================] - 0s 5ms/step
# 7/10	 test_acc:0.788235294117647
# 3/3 [==============================] - 0s 3ms/step
# 8/10	 test_acc:0.8690476190476191
# 3/3 [==============================] - 0s 2ms/step
# 9/10	 test_acc:0.788235294117647
# average accuracy : 0.8168767507002801

# %%
print("weights:", len(m_f.weights))
print("trainable_weights:", len(m_f.trainable_weights))
print("non_trainable_weights:", len(m_f.non_trainable_weights))
# Out:
# weights: 36
# trainable_weights: 0
# non_trainable_weights: 36

# %%
#m_f.trainable=False
m_f.summary()
# Out:
# Model: "Final_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  InputLayer (InputLayer)     [(None, 18)]              0
#
#  model_19 (Functional)       (None, 1296)              138113
#
#  sequential_19 (Sequential)  (None, 4)                 1815992
#
# =================================================================
# Total params: 1,954,105
# Trainable params: 1,813,400
# Non-trainable params: 140,705
# _________________________________________________________________

# %%
# 10fold validation 수행여부
bTenFoldValidation = True
if not bTenFoldValidation:  # 학습 & 테스트를 1회만 수행하는 경우
    # 데이터 분할
    [x_train, x_val, x_test, y_train, y_val, y_test] = exp.split_data(x, y, test_ratio=0.0, val_ratio=0.1)

    # 모델 불러오기 & 컴파일
    m = deep.get_model_gen(x.shape[1:])
    m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    # 학습시 사용하는 옵션
    train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=128)

    # 학습
    result = exp.train_batches_with_random_selection(train_options, x_train, y_train, x_val, y_val)

    # 테스트
    if(x_test.shape[0] > 0):
        test_acc_tmp = np.sum(np.argmax(np.squeeze(result.model.predict(x_test)), -1) == y_test) / y_test.shape[0]
        print(f'test_acc:{test_acc_tmp}')
    # 결과 출력

    plt.plot(result.train_acc)
    plt.plot(result.val_acc)
    plt.show()

else:  # N fold Validation
    idx = np.array(range(n_row))
    np.random.shuffle(idx)  # 데이터 인덱스 섞기

    N = 10
    total = 0
    nClass = 2
    cm = np.zeros([N, nClass, nClass])
    for i in range(N):
        # Train/Test 데이터 분할
        [x_train, x_test, y_train, y_test] = exp.split_data_for_N_fold_validation(x, y, fold=N, idx=i)

        # 모델 불러오기 & 컴파일
        m = deep.get_model_map_fun(x.shape[1:])
        #m = deep.get_model(x.shape[1:])

        # m = deep.get_model(x.shape[1:])
        m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

        # 학습시 사용하는 옵션
        train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=256)

        # 학습
        result = exp.train_batches_with_random_selection(train_options, x_train, y_train, bVerbose=False)

        #mapping block 학습 결과 저장
        intermediate_layer_model = tf.keras.Model(inputs=m.input, outputs=m.layers[9].output)
        intermediate_layer_model.trainable=False
        
        #final_model 불러오기
        m_f = deep.final_model(x.shape[1:], intermediate_layer_model, intermediate_layer_model.output.shape[1:])
        
        m_f.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
        
        train_options_f = exp.TrainParams(m_f, epochs=2000, batch_size_per_class=128)
        
        result_f = exp.train_batches_with_random_selection(train_options_f, x_train, y_train, bVerbose=False)
        
        # 테스트
        o = np.argmax(np.squeeze(result_f.model.predict(x_test)), -1)
        test_acc_tmp = np.sum(o == y_test) / y_test.shape[0]
        #for j in range(y_test.shape[0]):
            #cm[i, int(y_test[j]), int(o[j])] += 1  #Confusion Matrix 계산

        # 결과 출력
        print(f'{i}/{N}\t test_acc:{test_acc_tmp}')
        plt.plot(result_f.train_acc)
        plt.plot(result_f.val_acc)
        plt.show()
        total = total + test_acc_tmp

ave = total/10
print(f'average accuracy : {ave}')
# Out:
# 3/3 [==============================] - 0s 3ms/step
# 0/10	 test_acc:0.8470588235294118
# 3/3 [==============================] - 0s 2ms/step
# 1/10	 test_acc:0.8333333333333334
# 3/3 [==============================] - 0s 4ms/step
# 2/10	 test_acc:0.8235294117647058
# 3/3 [==============================] - 0s 5ms/step
# 3/10	 test_acc:0.8809523809523809
# 3/3 [==============================] - 0s 3ms/step
# 4/10	 test_acc:0.8
# 3/3 [==============================] - 0s 5ms/step
# 5/10	 test_acc:0.7647058823529411
# 3/3 [==============================] - 0s 4ms/step
# 6/10	 test_acc:0.7976190476190477
# 3/3 [==============================] - 0s 6ms/step
# 7/10	 test_acc:0.8117647058823529
# 3/3 [==============================] - 0s 4ms/step
# 8/10	 test_acc:0.8214285714285714
# 3/3 [==============================] - 0s 4ms/step
# 9/10	 test_acc:0.8235294117647058
# average accuracy : 0.820392156862745

# %%
intermediate_layer_model.output.shape[1:]
# Out:
# TensorShape([1296])

# %%
m_f.summary()
# Out:
# Model: "Final_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  InputLayer (InputLayer)     [(None, 18)]              0
#
#  model_89 (Functional)       (None, 1296)              138113
#
#  sequential_89 (Sequential)  (None, 4)                 1815992
#
# =================================================================
# Total params: 1,954,105
# Trainable params: 1,941,081
# Non-trainable params: 13,024
# _________________________________________________________________

# %% [markdown]
# Mapping Block + Resnet40

# %%
# 10fold validation 수행여부
bTenFoldValidation = True
if not bTenFoldValidation:  # 학습 & 테스트를 1회만 수행하는 경우
    # 데이터 분할
    [x_train, x_val, x_test, y_train, y_val, y_test] = exp.split_data(x, y, test_ratio=0.0, val_ratio=0.1)

    # 모델 불러오기 & 컴파일
    m = deep.get_model_gen(x.shape[1:])
    m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    # 학습시 사용하는 옵션
    train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=128)

    # 학습
    result = exp.train_batches_with_random_selection(train_options, x_train, y_train, x_val, y_val)

    # 테스트
    if(x_test.shape[0] > 0):
        test_acc_tmp = np.sum(np.argmax(np.squeeze(result.model.predict(x_test)), -1) == y_test) / y_test.shape[0]
        print(f'test_acc:{test_acc_tmp}')
    # 결과 출력

    plt.plot(result.train_acc)
    plt.plot(result.val_acc)
    plt.show()

else:  # N fold Validation
    idx = np.array(range(n_row))
    np.random.shuffle(idx)  # 데이터 인덱스 섞기

    N = 10
    total = 0
    nClass = 2
    cm = np.zeros([N, nClass, nClass])
    for i in range(N):
        # Train/Test 데이터 분할
        [x_train, x_test, y_train, y_test] = exp.split_data_for_N_fold_validation(x, y, fold=N, idx=i)

        # 모델 불러오기 & 컴파일
        m = deep.get_model_map_fun(x.shape[1:])
        #m = deep.get_model(x.shape[1:])

        # m = deep.get_model(x.shape[1:])
        m.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

        # 학습시 사용하는 옵션
        train_options = exp.TrainParams(m, epochs=2000, batch_size_per_class=256)

        # 학습
        result = exp.train_batches_with_random_selection(train_options, x_train, y_train, bVerbose=False)

        #mapping block 학습 결과 저장
        intermediate_layer_model = tf.keras.Model(inputs=m.input, outputs=m.layers[8].output)
        intermediate_layer_model.trainable=False
        
        #final_model 불러오기
        m_f = deep.ResNet50C(x.shape[1:], intermediate_layer_model)
        
        m_f.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
        
        train_options_f = exp.TrainParams(m_f, epochs=2000, batch_size_per_class=128)
        
        result_f = exp.train_batches_with_random_selection(train_options_f, x_train, y_train, bVerbose=False)
        
        # 테스트
        o = np.argmax(np.squeeze(result_f.model.predict(x_test)), -1)
        test_acc_tmp = np.sum(o == y_test) / y_test.shape[0]
        #for j in range(y_test.shape[0]):
            #cm[i, int(y_test[j]), int(o[j])] += 1  #Confusion Matrix 계산

        # 결과 출력
        print(f'{i}/{N}\t test_acc:{test_acc_tmp}')
        plt.plot(result_f.train_acc)
        plt.plot(result_f.val_acc)
        plt.show()
        total = total + test_acc_tmp

ave = total/10
print(f'average accuracy : {ave}')
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In [14], line 63
#      59 m_f.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
#      61 train_options_f = exp.TrainParams(m_f, epochs=2000, batch_size_per_class=128)
# ---> 63 result_f = exp.train_batches_with_random_selection(train_options_f, x_train, y_train, bVerbose=False)
#      65 # 테스트
#      66 o = np.argmax(np.squeeze(result_f.model.predict(x_test)), -1)
#
# File ~\generative_model\veichle\experiment.py:63, in train_batches_with_random_selection(train_parms, x_train, y_train, x_val, y_val, bVerbose)
#      60 y_train_batch = y_train_cat[idx_random, :]
#      62 # 학습
# ---> 63 loss = m.train_on_batch(x_train_batch, y_train_batch)
#      64 train_acc[i] = loss[1]
#      65 if bVerbose:
#
# File ~\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py:2381, in Model.train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2377     iterator = data_adapter.single_batch_iterator(
#    2378         self.distribute_strategy, x, y, sample_weight, class_weight
#    2379     )
#    2380     self.train_function = self.make_train_function()
# -> 2381     logs = self.train_function(iterator)
#    2383 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2384 if return_dict:
#
# File ~\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'ResNet50C/batch_normalization_69/FusedBatchNormV3' defined at (most recent call last):
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\asyncio\base_events.py", line 600, in run_forever
#       self._run_once()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\asyncio\base_events.py", line 1896, in _run_once
#       handle._run()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in run_cell
#       result = self._run_cell(
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py", line 2995, in _run_cell
#       return runner(coro)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py", line 3194, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py", line 3373, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\kyeongtaek\AppData\Local\Temp\ipykernel_17556\1459044735.py", line 63, in <module>
#       result_f = exp.train_batches_with_random_selection(train_options_f, x_train, y_train, bVerbose=False)
#     File "C:\Users\kyeongtaek\generative_model\veichle\experiment.py", line 63, in train_batches_with_random_selection
#       loss = m.train_on_batch(x_train_batch, y_train_batch)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 2381, in train_on_batch
#       logs = self.train_function(iterator)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 850, in call
#       outputs = self._fused_batch_norm(inputs, training=training)
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 660, in _fused_batch_norm
#       output, mean, variance = control_flow_util.smart_cond(
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\utils\control_flow_util.py", line 108, in smart_cond
#       return tf.__internal__.smart_cond.smart_cond(
#     File "C:\Users\kyeongtaek\anaconda3\envs\tensor\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 634, in _fused_batch_norm_training
#       return tf.compat.v1.nn.fused_batch_norm(
# Node: 'ResNet50C/batch_normalization_69/FusedBatchNormV3'
# OOM when allocating tensor with shape[512,256,9,9] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node ResNet50C/batch_normalization_69/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_77784]

# %%
m_f.summary()
# Out:
# Model: "ResNet50C"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 18)]         0           []
#
#  model_2 (Functional)           (None, 36, 36, 1)    138113      ['input_3[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 36, 36, 64)   640         ['model_2[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 36, 36, 64)  256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_38[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 36, 36, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 36, 36, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_40[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_38[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 36, 36, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 36, 36, 64)  256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 36, 36, 64)   0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_41 (Activation)     (None, 36, 36, 64)   0           ['add_12[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_41[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 36, 36, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 36, 36, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 36, 36, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 36, 36, 64)   0           ['batch_normalization_49[0][0]',
#                                                                   'activation_41[0][0]']
#
#  activation_44 (Activation)     (None, 36, 36, 64)   0           ['add_13[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_44[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 36, 36, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 36, 36, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 36, 36, 64)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 36, 36, 64)   36928       ['activation_46[0][0]']
#  batch_normalization_52 (BatchN  (None, 36, 36, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 36, 36, 64)   0           ['batch_normalization_52[0][0]',
#                                                                   'activation_44[0][0]']
#
#  activation_47 (Activation)     (None, 36, 36, 64)   0           ['add_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 18, 18, 64)  0           ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 18, 18, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 18, 18, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 18, 18, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_49[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 18, 18, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 18, 18, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 18, 18, 128)  512        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 18, 18, 128)  0           ['batch_normalization_55[0][0]',
#                                                                   'batch_normalization_56[0][0]']
#
#  activation_50 (Activation)     (None, 18, 18, 128)  0           ['add_15[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_50[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 18, 18, 128)  512        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_51[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 18, 18, 128)  512        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_52[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 18, 18, 128)  512        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 18, 18, 128)  0           ['batch_normalization_59[0][0]',
#                                                                   'activation_50[0][0]']
#
#  activation_53 (Activation)     (None, 18, 18, 128)  0           ['add_16[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_53[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 18, 18, 128)  512        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 18, 18, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 18, 18, 128)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 18, 18, 128)  147584      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 18, 18, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 18, 18, 128)  0           ['batch_normalization_62[0][0]',
#                                                                   'activation_53[0][0]']
#
#  activation_56 (Activation)     (None, 18, 18, 128)  0           ['add_17[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 9, 9, 128)   0           ['activation_56[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 9, 9, 256)    295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_58[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 9, 9, 256)    295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_66[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 9, 9, 256)    0           ['batch_normalization_65[0][0]',
#                                                                   'batch_normalization_66[0][0]']
#
#  activation_59 (Activation)     (None, 9, 9, 256)    0           ['add_18[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_59[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_60[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_61[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 9, 9, 256)    0           ['batch_normalization_69[0][0]',
#                                                                   'activation_59[0][0]']
#
#  activation_62 (Activation)     (None, 9, 9, 256)    0           ['add_19[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_62[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_63[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 9, 9, 256)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 9, 9, 256)    590080      ['activation_64[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 9, 9, 256)   1024        ['conv2d_72[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 9, 9, 256)    0           ['batch_normalization_72[0][0]',
#                                                                   'activation_62[0][0]']
#
#  activation_65 (Activation)     (None, 9, 9, 256)    0           ['add_20[0][0]']
#  max_pooling2d_6 (MaxPooling2D)  (None, 5, 5, 256)   0           ['activation_65[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 5, 5, 512)    1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_66[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_67[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 5, 5, 512)    1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_75[0][0]']
#  ormalization)
#
#  batch_normalization_76 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_76[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 5, 5, 512)    0           ['batch_normalization_75[0][0]',
#                                                                   'batch_normalization_76[0][0]']
#
#  activation_68 (Activation)     (None, 5, 5, 512)    0           ['add_21[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_68[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_69[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_78[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_70[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_79[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 5, 5, 512)    0           ['batch_normalization_79[0][0]',
#                                                                   'activation_68[0][0]']
#
#  activation_71 (Activation)     (None, 5, 5, 512)    0           ['add_22[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_71[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_72[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 5, 5, 512)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 5, 5, 512)    2359808     ['activation_73[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 5, 5, 512)   2048        ['conv2d_82[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 5, 5, 512)    0           ['batch_normalization_82[0][0]',
#                                                                   'activation_71[0][0]']
#
#  activation_74 (Activation)     (None, 5, 5, 512)    0           ['add_23[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 512)   0           ['activation_74[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['max_pooling2d_7[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 4)            2052        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 28,426,885
# Trainable params: 28,269,444
# Non-trainable params: 157,441
# __________________________________________________________________________________________________
